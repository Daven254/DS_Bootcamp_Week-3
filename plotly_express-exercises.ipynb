# %% [markdown]
# ## PLOTLY EXPRESS/PLOTLY EXPRESS PART 1 EXERCISE  ##
# #### Exercise 1 ####
# #### Task 1
# ##### Import the Plotly Express library as px
# ##### Use the Plotly Express library to pull in the dataset `iris` and save it as df
# #### Result:

# %%
import plotly.express as px
df = px.data.iris()

df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %% [markdown]
# #### Task 2
# ##### Create a histogram of petal_length colored by species. Add a title, choose a number of bins, and change the axes labels, and the color palette as you see fit.
# #### Result:

# %%
fig = px.histogram(
    df, x="petal_length", 
    color="species", 
    hover_data=df.columns, 
    title='Petal Lengths by Species', 
    labels={'petal_length': 'Petal Length'}, 
    nbins=50, 
    color_discrete_sequence=px.colors.sequential.Aggrnyl)

fig.show()

# %% [markdown]
# #### Task 3
# ##### Create a box plot of `sepal_length` colored by species.  Add a title, change axes labels, and the color palette as you see fit.
# #### Result:

# %%
fig = px.box(df, x = 'sepal_length' , 
             color = 'species', 
             title = 'Sepal Lengths per Species', 
             labels={'sepal_length':'Sepal Length'}) 


fig.show()

# %% [markdown]
# ## PLOTLY EXPRESS/PLOTLY EXPRESS PART 2 EXERCISE  ##
# #### Exercise 2 ####
# #### Task 1
# ##### Import the Plotly Express library as px
# ##### Use the Plotly Express library to pull in the dataset `experiment` and save it as `expsdf`
# ##### Load in `stocks` as `stocksdf`
# #### Result:

# %%
import plotly.express as px
expsdf = px.data.experiment()
expsdf
# Out:
#     experiment_1  experiment_2  experiment_3  gender      group
# 0      96.876065     93.417942     73.033193    male    control
# 1      87.301336    129.603395     66.056554  female    control
# 2      97.691312    106.187916    103.422709    male  treatment
# 3     102.978152     93.814682     56.995870  female  treatment
# 4      87.106993    107.019985     72.140292    male    control
# ..           ...           ...           ...     ...        ...
# 95    108.156964    105.971541     64.524029  female  treatment
# 96     91.739992    111.125377     64.260993    male    control
# 97     95.410347     84.448322     75.505991  female    control
# 98    106.362406    115.522382    123.469689    male  treatment
# 99     94.269237    104.651064     92.387490  female  treatment
#
# [100 rows x 5 columns]

# %%
stocksdf = px.data.stocks()
stocksdf
# Out:
#            date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0    2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1    2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2    2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3    2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4    2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# ..          ...       ...       ...       ...       ...       ...       ...
# 100  2019-12-02  1.216280  1.546914  1.425061  1.075997  1.463641  1.720717
# 101  2019-12-09  1.222821  1.572286  1.432660  1.038855  1.421496  1.752239
# 102  2019-12-16  1.224418  1.596800  1.453455  1.104094  1.604362  1.784896
# 103  2019-12-23  1.226504  1.656000  1.521226  1.113728  1.567170  1.802472
# 104  2019-12-30  1.213014  1.678000  1.503360  1.098475  1.540883  1.788185
#
# [105 rows x 7 columns]

# %% [markdown]
# #### Task 2
# ##### Create a scatter plot using exps, plot experiment_1 versus experiment_2, coloring by group.
# #### Result:

# %%
fig = px.scatter(expsdf,x = 'experiment_1', y = 'experiment_2' , color = 'group',trendline = 'ols')
fig.show()

# %% [markdown]
# #### Task 3
# ##### Use the code from Task 2 and create a linear regression by group.  Show the model summary for your group of choice.  Is this a good model?
# #### Result:

# %%
results=px.get_trendline_results(fig)
results
# Out:
#        group                                     px_fit_results
# 0    control  <statsmodels.regression.linear_model.Regressio...
# 1  treatment  <statsmodels.regression.linear_model.Regressio...

# %%
query_results = results.query("group=='control'")

# %%
query_results.px_fit_results.iloc[0].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9440
# Date:                Mon, 08 Aug 2022   Prob (F-statistic):              0.336
# Time:                        18:44:44   Log-Likelihood:                -195.95
# No. Observations:                  50   AIC:                             395.9
# Df Residuals:                      48   BIC:                             399.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         89.9603     20.673      4.352      0.000      48.395     131.525
# x1             0.1989      0.205      0.972      0.336      -0.213       0.611
# ==============================================================================
# Omnibus:                        1.149   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.563   Jarque-Bera (JB):                0.995
# Skew:                           0.118   Prob(JB):                        0.608
# Kurtosis:                       2.350   Cond. No.                     1.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# R-squared is really low, so the model cannot really explain the variance of the dependent variable (exp2).
#
# p(t-test) is also not very good, it is too high. This suggests that the independent variable (exp1) is not a strong indicator of model to predict exp2.
#
# p(f-stat) is high as well. This means that the model does not have predictive strength to predict the dependent variable based on the independent variable.
#
# The p(JB) value is high. This implies that the residuals are normally distributed.

# %% [markdown]
# #### Task 4
# ##### Create a line plot using the stocksdf.  Use pandas and melt to make the data long for plotting all the stocks on the same plot. Use the code below:

# %%
import pandas as pd
stocksdf_long=pd.melt(stocksdf, id_vars='date', value_name='Value', var_name='Stock')

# %% [markdown]
# ##### Plot each line colored by Stock
# #### Result:

# %%
px.line(stocksdf_long,x = 'date',y = 'Value', color = 'Stock')

# %% [markdown]
# #### Task 5
# ##### Create a Scatter Matrix using the expsdf data.
# ##### Save the figure as an html file.
# #### Result:

# %%
cormat=expsdf.corr()
fig = px.imshow(cormat, zmin=-1, zmax=1)
fig.show()

# %% [markdown]
# ## PLOTLY EXPRESS/PLOTLY EXPRESS PART 3 EXERCISE  ##
# #### Exercise 3 ####
# #### Task 1
# ##### Import the Plotly Express library as px
# ##### Use the Plotly Express library to pull in the dataset `election` and save it as `eldf`
# ##### Load in `gapminder` as `gapdf`
# ##### Load in `experiment` as `expdf`.
# #### Result:

# %%
gapdf = px.data.gapminder()
expdf = px.data.experiment()

# %% [markdown]
# #### Task 2
# ##### Create a correlation plot using a subset of expdf which includes the columns `experiment_1`, `experiment_2`, and  `experiment_3`. Which of these are correlated?
# #### Result:

# %%
cormat = expdf.corr()
fig = px.imshow(cormat, zmin=-1, zmax=1)
fig.show()

# %% [markdown]
# #### Task 3
# ##### Create a density heatmap of `experiment_1` and `experiment_3`.  Would both of these contribute to a model?
# #### Result:

# %%
fig = px.density_heatmap(expdf,x = 'experiment_1', y = 'experiment_3')
fig.show()

# %% [markdown]
# #### Task 4
# ##### Use gapdf and create a choropleth map of `gdpPercap` in year 1982 for the world.
# #### Result:

# %%
gapdf_1982 = gapdf.query("year == 1982")

# %%
fig = px.choropleth(gapdf_1982, locations="iso_alpha",
                    color="lifeExp", # lifeExp is a column of gapminder
                    hover_name="country", # column to add to hover information
                    color_continuous_scale=px.colors.sequential.Agsunset_r)
fig.show()

# %% [markdown]
# #### Task 5
# ##### Use `eldf` and load in the geoJSON that goes with it to make a map of the votes for Coderre.
# #### Result:

# %%
geojson = px.data.election_geojson()
eldf = px.data.election()


fig = px.choropleth(eldf, geojson=geojson, 
                    color="Coderre",
                    locations="district", 
                    featureidkey="properties.district", color_continuous_scale=px.colors.sequential.Agsunset_r,
                    projection="mercator"
                   )

fig.update_geos(fitbounds="locations", visible=False)
fig.show()

# %% [markdown]
# #### Task 6
# ##### Use `gapdf` to create an animation of `gdpPercap` over the world by using year as the `animation_frame`.
# #### Result:

# %%
locations = 'iso_alpha'
fig = px.choropleth(gapdf, animation_frame = 'year' , locations = 'iso_alpha',color="lifeExp", # lifeExp is a column of gapminder
                    hover_name="country", # column to add to hover information
                    color_discrete_sequence=px.colors.qualitative.G10)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})


fig.show()
